# %%
import commonLib as cl
import numpy as np
import matplotlib.pyplot as plt

# Print statements for these in jupyter output
print(cl.call_from_cpp(8.3)) 
print(cl.call_from_fortran(8.3))

print(cl.iseven(8))
print(cl.isodd(8))

print(dir(cl))
# Out:
# 8.300000190734863
# 8.300000190734863
# True
# False
# ['__builtins__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__pyx_unpickle_Enum', '__spec__', '__test__', 'add2', 'call_from_cpp', 'call_from_fortran', 'iseven', 'isodd', 'np', 'wave_propogation_cython', 'wave_propogation_fortran']

# %%
x = cl.add2(3)
print(x)
# Out:
# 5.0

# %%
num_steps = 100
scale = 50
damping= 0.25
initial_p = 1
stop_step = 1

p_c = cl.wave_propogation_cython(num_steps, scale, damping, initial_p, stop_step)

plt.imshow(p_c)
plt.show()

p_f = cl.wave_propogation_fortran(num_steps, scale, damping, initial_p, stop_step)

plt.imshow(p_f)
plt.show()

print(np.sum(p_c-p_f)) # Small errors due to the python float conversions
# Out:
# 1.1913478e-05

# %%
# %%timeit
num_steps = 100
scale = 50
damping= 0.25
initial_p = 1
stop_step = 1

p_c = cl.wave_propogation_cython(num_steps, scale, damping, initial_p, stop_step)
# Out:
# 3.8 ms ± 161 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
num_steps = 100
scale = 50
damping= 0.25
initial_p = 1
stop_step = 1

p_f = cl.wave_propogation_fortran(num_steps, scale, damping, initial_p, stop_step)
# Out:
# 18.9 ms ± 873 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
print(type(p_c),type(p_f))
# Out:
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>
