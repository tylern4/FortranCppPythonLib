# %%
import libfort as lib
import numpy as np
import matplotlib.pyplot as plt

# %%
print(dir(lib))
# Out:
# ['__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '__version__', '_libfort_error', 'calling_from_fortran', 'even', 'odd', 'wave_propogation']
# p = wave_propogation(num_steps,scale,damping,initial_p,stop_step)
#
# Wrapper for ``wave_propogation``.
#
# Parameters
# ----------
# num_steps : input int
# scale : input int
# damping : input float
# initial_p : input float
# stop_step : input int
#
# Returns
# -------
# p : rank-2 array('f') with bounds (2 * scale + 1,2 * scale + 1)

# %%
print(lib.calling_from_fortran(3.0))
# Out:
# 3.0

# %%
print(lib.even(4))
# Out:
# 1

# %%
print(lib.odd(4))
# Out:
# 0

# %%
num_steps = 100
scale = 50
damping= 0.25
initial_p = 1
stop_step = 1

p = lib.wave_propogation(num_steps, scale, damping, initial_p, stop_step)

plt.imshow(p)
plt.show()
